# %% [markdown]
# # MASTER DARK

# %% [markdown]
# The final step is to combine the individual calibrated dark images into a single
# combined image. That combined image will have less noise than the individual
# images, minimizing the noise added to the remaining images when the dark is
# subtracted.
#
# Regardless of which path you took through the calibration of the biases (with
# overscan or without) there should be a folder named either `example1-reduced` or
# `example2-reduced` that contains the calibrated bias and dark images. If there
# is not, please run the previous notebook before continuing with this one.

# %%
from pathlib import Path
import os

from astropy.nddata import CCDData
from astropy.stats import mad_std

import ccdproc as ccdp
import matplotlib.pyplot as plt
import numpy as np

from convenience_functions import show_image

# %%
# Use custom style for larger fonts and figures
#plt.style.use('guide.mplstyle')
print(plt.style.available)
plt.style.use('grayscale')
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %% [markdown]
# ## Recommended settings for image combination
#
# As discussed in the [notebook about combining images](01-06-Image-combination.ipynb), the recommendation is
# that you combine by averaging the individual images but sigma clip to remove
# extreme values.
#
# [ccdproc](https://ccdproc.readthedocs.org) provides two ways to combine:
#
# + An object-oriented interface built around the `Combiner` object, described in
# the [ccdproc documentation on image combination](https://ccdproc.readthedocs.io/en/latest/image_combination.html).
# + A function called [`combine`](https://ccdproc.readthedocs.io/en/latest/api/ccdproc.combine.html#ccdproc.combine), which we will use here because the function
# allows you to specify the maximum amount of memory that should be used during
# combination. That feature can be essential depending on how many images you need
# to combine, how big they are, and how much memory your computer has.
#
# *NOTE: If using a version of ccdproc lower than 2.0, set the memory limit a
# factor of 2-3 lower than you want the maximum memory consumption to be.*

# %% [markdown]
# ## Example 1: Cryogenically-cooled camera

# %% [markdown]
# The remainder of this section assumes that the calibrated bias images are in the
# folder `example1-reduced` which was created in the previous notebook.

# %%
calibrated_path = Path('example1-reduced')
reduced_images = ccdp.ImageFileCollection(calibrated_path)

# %% [markdown]
# ### Make a combined image for each exposure time in Example 1

# %% [markdown]
# There are several dark exposure times in this data set. By converting the times
# in the summary table to a set it returns only the unique values.

# %%
darks = reduced_images.summary['imagetyp'] == 'Dark Frame'
dark_times = set(reduced_images.summary['exptime'][darks])
print(dark_times)
# Out:
# {0.5873153, 0.634, 0.2382926, 4.571774, 200.0}

# %% [markdown]
# Il codice seguente esegue un loop sui tempi di esposizione delle dark e, per ogni tempo di esposizione:
#
# + seleziona le dark
# + le combina utilizzando la funzione `combine`,
# + aggiunge la parola chiave `COMBINED` all'header, in modo che le fasi successive di calibrazione possano
# identificare facilmente quale bias utilizzare
# + crea i file (nella denominazione appare il tempo di esposizione)

# %%
for exp_time in sorted(dark_times):
    calibrated_darks = reduced_images.files_filtered(imagetyp='Dark Frame', exptime=exp_time,
                                                     include_path=True)
    combined_dark = ccdp.combine(calibrated_darks,
                                 method='average',
                                 sigma_clip=True, sigma_clip_low_thresh=5, sigma_clip_high_thresh=5,
                                 sigma_clip_func=np.ma.median, sigma_clip_dev_func=mad_std,
                                 mem_limit=350e6,
                                 unit='adu' 
                                )
    combined_dark.meta['combined'] = True

    dark_file_name = 'combined_dark_{:6.3f}.fits'.format(exp_time)
    combined_dark.write(calibrated_path / dark_file_name)
# Out:
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59783.159059 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59783.159059 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59783.159090 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59783.159090 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59783.159119 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59783.159119 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59783.159149 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59783.159149 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59783.159178 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59783.159178 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59783.159207 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59783.159207 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59783.159238 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59783.159238 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59783.159266 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59783.159266 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59783.159296 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59783.159296 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59783.159324 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59783.159324 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59783.159361 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59783.159361 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59783.159397 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59783.159397 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59783.159432 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59783.159432 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59783.159468 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59783.159468 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59783.159504 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59783.159504 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59783.159540 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59783.159540 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59783.159576 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59783.159576 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59783.159612 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59783.159612 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59783.162582 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59783.162582 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59783.162619 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59783.162619 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59783.162651 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59783.162651 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59783.162688 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59783.162688 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59783.162724 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59783.162724 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59783.162761 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59783.162761 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59783.162798 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59783.162798 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59783.162834 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59783.162834 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59783.162870 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59783.162870 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59783.147714 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59783.147714 from DATE-OBS'.
# INFO:astropy:using the unit adu passed to the FITS reader instead of the unit adu in the FITS file.
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
#      11 combined_dark.meta['combined'] = True
#      13 dark_file_name = 'combined_dark_{:6.3f}.fits'.format(exp_time)
# ---> 14 combined_dark.write(calibrated_path / dark_file_name)
#
# File /mnt/300GB/miniconda3/lib/python3.9/site-packages/astropy/nddata/mixins/ndio.py:103, in NDDataWrite.__call__(self, *args, **kwargs)
#     102 def __call__(self, *args, **kwargs):
# --> 103     self.registry.write(self._instance, *args, **kwargs)
#
# File /mnt/300GB/miniconda3/lib/python3.9/site-packages/astropy/io/registry/core.py:369, in UnifiedOutputRegistry.write(self, data, format, *args, **kwargs)
#     365     format = self._get_valid_format(
#     366         'write', data.__class__, path, fileobj, args, kwargs)
#     368 writer = self.get_writer(format, data.__class__)
# --> 369 return writer(data, *args, **kwargs)
#
# File /mnt/300GB/miniconda3/lib/python3.9/site-packages/astropy/nddata/ccddata.py:731, in fits_ccddata_writer(ccd_data, filename, hdu_mask, hdu_uncertainty, hdu_flags, key_uncertainty_type, as_image_hdu, **kwd)
#     729 if as_image_hdu:
#     730     hdu.insert(0, fits.PrimaryHDU())
# --> 731 hdu.writeto(filename, **kwd)
#
# File /mnt/300GB/miniconda3/lib/python3.9/site-packages/astropy/io/fits/hdu/hdulist.py:939, in HDUList.writeto(self, fileobj, output_verify, overwrite, checksum)
#     935 mode = FILE_MODES[fileobj_mode(fileobj)] if isfile(fileobj) else 'ostream'
#     937 # This can accept an open file object that's open to write only, or in
#     938 # append/update modes but only if the file doesn't exist.
# --> 939 fileobj = _File(fileobj, mode=mode, overwrite=overwrite)
#     940 hdulist = self.fromfile(fileobj)
#     941 try:
#
# File /mnt/300GB/miniconda3/lib/python3.9/site-packages/astropy/io/fits/file.py:170, in _File.__init__(self, fileobj, mode, memmap, overwrite, cache)
#     168     self._open_fileobj(fileobj, mode, overwrite)
#     169 elif isinstance(fileobj, (str, bytes)):
# --> 170     self._open_filename(fileobj, mode, overwrite)
#     171 else:
#     172     self._open_filelike(fileobj, mode, overwrite)
#
# File /mnt/300GB/miniconda3/lib/python3.9/site-packages/astropy/io/fits/file.py:551, in _File._open_filename(self, filename, mode, overwrite)
#     548 """Open a FITS file from a filename string."""
#     550 if mode == 'ostream':
# --> 551     self._overwrite_existing(overwrite, None, True)
#     553 if os.path.exists(self.name):
#     554     with open(self.name, 'rb') as f:
#
# File /mnt/300GB/miniconda3/lib/python3.9/site-packages/astropy/io/fits/file.py:440, in _File._overwrite_existing(self, overwrite, fileobj, closed)
#     438         os.remove(self.name)
#     439 else:
# --> 440     raise OSError(NOT_OVERWRITING_MSG.format(self.name))
#
# OSError: File example1-reduced/combined_dark_ 4.572.fits already exists. If you mean to replace it then use the argument "overwrite=True".

# %% [markdown]
# ### Result for Example 1

# %% [markdown]
# A single calibrated 300 second dark image and the combined 300 second image are
# shown below.

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 10))

show_image(CCDData.read(calibrated_darks[0], unit='adu').data, cmap='gray', ax=ax1, fig=fig)
ax1.set_title('Single calibrated dark')
show_image(combined_dark.data, cmap='gray', ax=ax2, fig=fig)
ax2.set_title('{} dark images combined'.format(len(calibrated_darks)))
# Out:
# Text(0.5, 1.0, '2 dark images combined')
